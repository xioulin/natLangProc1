# %%
import pandas as pd
import os

# %%
df= pd.read_csv('epl_seasons1/season_2004-05.csv')
df
# Out:
#     Div      Date       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    E0  14/08/04    Aston Villa  Southampton     2     0   H     2     0   H
# 1    E0  14/08/04      Blackburn    West Brom     1     1   D     0     1   A
# 2    E0  14/08/04         Bolton     Charlton     4     1   H     2     0   H
# 3    E0  14/08/04       Man City       Fulham     1     1   D     1     0   H
# 4    E0  14/08/04  Middlesbrough    Newcastle     2     2   D     0     1   A
# ..   ..       ...            ...          ...   ...   ...  ..   ...   ...  ..
# 330  E0  20/04/05        Everton   Man United     1     0   H     0     0   D
# 331  E0  20/04/05       Man City   Birmingham     3     0   H     0     0   D
# 332  E0  20/04/05        Norwich    Newcastle     2     1   H     0     0   D
# 333  E0  20/04/05     Portsmouth    Liverpool     1     2   A     1     2   A
# 334  E0  20/04/05      Tottenham    West Brom     1     1   D     0     1   A
#
# ...

# %%
df= pd.read_csv('epl_seasons1/season_1993-94.csv')
dropped= df.dropna(axis='columns', how='all')
dropped.to_csv('epl_seasons1/season_1993-94.csv', index=False)

# %%
path="epl_seasons1"
dir_list= os.listdir(path)
for i in dir_list:
    print(i)
    df=pd.read_csv('epl_seasons1/'+i,on_bad_lines='skip')
    drop=df.dropna(axis='columns', how='all')
    drop.to_csv('epl_seasons1/'+i, index=False)
# Out:
# season_00-01.csv
# season_01-02.csv
# season_02-03.csv
# season_03-04.csv
# season_04-05.csv
# season_05-06.csv
# season_06-07.csv
# season_07-08.csv
# season_08-09.csv
# season_09-10.csv
# season_10-11.csv
# season_11-12.csv
# season_12-13.csv
# season_13-14.csv
# season_14-15.csv
# season_15-16.csv
# season_16-17.csv
# season_17-18.csv
# season_18-19.csv
# season_19-20.csv
# season_20-21.csv
# season_21-22.csv
# season_22-23.csv
# season_23-24.csv
# season_24-25.csv
# season_93-94.csv
# season_94-95.csv
# season_95-96.csv
# season_96-97.csv
# season_97-98.csv
# season_98-99.csv
# season_99-00.csv
