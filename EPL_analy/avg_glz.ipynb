# %%
import pandas as pd
import os

import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('epl_seasons1/season_1993-94.csv')

# %%
csv_list=[]
for i in os.listdir('epl_seasons1'):
    csv_list.append(i)

# %%
df_list=[]
for i in csv_list:
    df=pd.read_csv('epl_seasons1/'+i)
    df_list.append(df)

# %%
df1= df_list[0]

# %%
seez_gl_avg=[]
for i in range(len(df_list)):
    seez_gl_avg.append(df_list[i].FTHG.mean())

# %%
seez_gl_avg
# Out:
# [np.float64(1.4350649350649352),
#  np.float64(1.5086580086580086),
#  np.float64(1.5263157894736843),
#  np.float64(1.4710526315789474),
#  np.float64(1.5578947368421052),
#  np.float64(1.4552631578947368),
#  np.float64(1.6710526315789473),
#  np.float64(1.5447368421052632),
#  np.float64(1.4657894736842105),
#  np.float64(1.5),
#  np.float64(1.492537313432836),
#  np.float64(1.4686567164179105),
#  np.float64(1.4605263157894737),
#  np.float64(1.4526315789473685),
#  np.float64(1.5289473684210526),
#  np.float64(1.4),
#  np.float64(1.6973684210526316),
#  np.float64(1.6236842105263158),
#  np.float64(1.5894736842105264),
#  np.float64(1.5578947368421052),
#  np.float64(1.5736842105263158),
#  np.float64(1.4736842105263157),
#  np.float64(1.4921052631578948),
#  np.float64(1.5973684210526315),
#  np.float64(1.5315789473684212),
#  np.float64(1.568421052631579),
#  np.float64(1.5157894736842106),
#  np.float64(1.3526315789473684),
#  np.float64(1.513157894736842),
# ...

# %%
plt.plot(seez_gl_avg)
